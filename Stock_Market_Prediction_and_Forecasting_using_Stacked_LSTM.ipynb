# %% [markdown]
# # Dataset Link: https://raw.githubusercontent.com/mwitiderrick/stockprice/master/NSE-TATAGLOBAL.csv

# %% [markdown]
# # Loading the dataset

# %%
import numpy as np
import pandas as pd

df = pd.read_csv("NSE-TATAGLOBAL.csv")
df
# Out:
#             Date    Open    High     Low    Last   Close  \
# 0     2018-09-28  234.05  235.95  230.20  233.50  233.75
# 1     2018-09-27  234.55  236.80  231.10  233.80  233.25
# 2     2018-09-26  240.00  240.00  232.50  235.00  234.25
# 3     2018-09-25  233.30  236.75  232.00  236.25  236.10
# 4     2018-09-24  233.55  239.20  230.75  234.00  233.30
# ...          ...     ...     ...     ...     ...     ...
# 2030  2010-07-27  117.60  119.50  112.00  118.80  118.65
# 2031  2010-07-26  120.10  121.00  117.10  117.10  117.60
# 2032  2010-07-23  121.80  121.95  120.25  120.35  120.65
# 2033  2010-07-22  120.30  122.00  120.25  120.75  120.90
# 2034  2010-07-21  122.10  123.00  121.05  121.10  121.55
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                  3069914          7162.35
# 1                  5082859         11859.95
# 2                  2240909          5248.60
# 3                  2349368          5503.90
# 4                  3423509          7999.55
# ...                    ...              ...
# 2030                586100           694.98
# 2031                658440           780.01
# 2032                281312           340.31
# 2033                293312           355.17
# 2034                658666           803.56
#
# [2035 rows x 8 columns]

# %% [markdown]
# #   Understanding Data

# %%
df = df[::-1]
df
# Out:
#             Date    Open    High     Low    Last   Close  \
# 2034  2010-07-21  122.10  123.00  121.05  121.10  121.55
# 2033  2010-07-22  120.30  122.00  120.25  120.75  120.90
# 2032  2010-07-23  121.80  121.95  120.25  120.35  120.65
# 2031  2010-07-26  120.10  121.00  117.10  117.10  117.60
# 2030  2010-07-27  117.60  119.50  112.00  118.80  118.65
# ...          ...     ...     ...     ...     ...     ...
# 4     2018-09-24  233.55  239.20  230.75  234.00  233.30
# 3     2018-09-25  233.30  236.75  232.00  236.25  236.10
# 2     2018-09-26  240.00  240.00  232.50  235.00  234.25
# 1     2018-09-27  234.55  236.80  231.10  233.80  233.25
# 0     2018-09-28  234.05  235.95  230.20  233.50  233.75
#
#       Total Trade Quantity  Turnover (Lacs)
# 2034                658666           803.56
# 2033                293312           355.17
# 2032                281312           340.31
# 2031                658440           780.01
# 2030                586100           694.98
# ...                    ...              ...
# 4                  3423509          7999.55
# 3                  2349368          5503.90
# 2                  2240909          5248.60
# 1                  5082859         11859.95
# 0                  3069914          7162.35
#
# [2035 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2035 entries, 2034 to 0
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  2035 non-null   object
#  1   Open                  2035 non-null   float64
#  2   High                  2035 non-null   float64
#  3   Low                   2035 non-null   float64
#  4   Last                  2035 non-null   float64
#  5   Close                 2035 non-null   float64
#  6   Total Trade Quantity  2035 non-null   int64
#  7   Turnover (Lacs)       2035 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 143.1+ KB

# %%
df.describe()
# Out:
#               Open         High          Low         Last       Close  \
# count  2035.000000  2035.000000  2035.000000  2035.000000  2035.00000
# mean    149.713735   151.992826   147.293931   149.474251   149.45027
# std      48.664509    49.413109    47.931958    48.732570    48.71204
# min      81.100000    82.800000    80.000000    81.000000    80.95000
# 25%     120.025000   122.100000   118.300000   120.075000   120.05000
# 50%     141.500000   143.400000   139.600000   141.100000   141.25000
# 75%     157.175000   159.400000   155.150000   156.925000   156.90000
# max     327.700000   328.750000   321.650000   325.950000   325.75000
#
#        Total Trade Quantity  Turnover (Lacs)
# count          2.035000e+03      2035.000000
# mean           2.335681e+06      3899.980565
# std            2.091778e+06      4570.767877
# min            3.961000e+04        37.040000
# 25%            1.146444e+06      1427.460000
# 50%            1.783456e+06      2512.030000
# 75%            2.813594e+06      4539.015000
# max            2.919102e+07     55755.080000

# %%
df.drop_duplicates(inplace = True)
df
# Out:
#             Date    Open    High     Low    Last   Close  \
# 2034  2010-07-21  122.10  123.00  121.05  121.10  121.55
# 2033  2010-07-22  120.30  122.00  120.25  120.75  120.90
# 2032  2010-07-23  121.80  121.95  120.25  120.35  120.65
# 2031  2010-07-26  120.10  121.00  117.10  117.10  117.60
# 2030  2010-07-27  117.60  119.50  112.00  118.80  118.65
# ...          ...     ...     ...     ...     ...     ...
# 4     2018-09-24  233.55  239.20  230.75  234.00  233.30
# 3     2018-09-25  233.30  236.75  232.00  236.25  236.10
# 2     2018-09-26  240.00  240.00  232.50  235.00  234.25
# 1     2018-09-27  234.55  236.80  231.10  233.80  233.25
# 0     2018-09-28  234.05  235.95  230.20  233.50  233.75
#
#       Total Trade Quantity  Turnover (Lacs)
# 2034                658666           803.56
# 2033                293312           355.17
# 2032                281312           340.31
# 2031                658440           780.01
# 2030                586100           694.98
# ...                    ...              ...
# 4                  3423509          7999.55
# 3                  2349368          5503.90
# 2                  2240909          5248.60
# 1                  5082859         11859.95
# 0                  3069914          7162.35
#
# [2035 rows x 8 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
df_high = df.reset_index()['High']
df_high
# Out:
# 0       123.00
# 1       122.00
# 2       121.95
# 3       121.00
# 4       119.50
#          ...
# 2030    239.20
# 2031    236.75
# 2032    240.00
# 2033    236.80
# 2034    235.95
# Name: High, Length: 2035, dtype: float64

# %%
plt.plot(df_high)
plt.show()

# %% [markdown]
# # Preprocessing

# %%
from sklearn.preprocessing import MinMaxScaler

MMS = MinMaxScaler()
df_high = MMS.fit_transform(df_high.values.reshape(-1, 1))
df_high
# Out:
# array([[0.16344786],
#        [0.15938199],
#        [0.15917869],
#        ...,
#        [0.6391543 ],
#        [0.62614353],
#        [0.62268754]])

# %% [markdown]
# # Train & Test Split

# %%
train_size = int(len(df_high) * 0.8)
test_size = len(df_high) - train_size

train_size, test_size
# Out:
# (1628, 407)

# %%
train_data, test_data = df_high[:train_size, :], df_high[train_size:, :1]
train_data.shape
# Out:
# (1628, 1)

# %% [markdown]
# # Preparing Data

# %%
# Previous 100 data points are stored 

def create_data(data, time_step):
  X_data, y_data = [], []

  for i in range(len(data) - time_step - 1):
    prev = data[i: i+time_step, 0]
    X_data.append(prev)
    y_data.append(data[i+time_step, 0])

  return np.array(X_data), np.array(y_data)

# %%
time_step = 100

X_train, y_train = create_data(train_data, time_step)
X_test, y_test = create_data(test_data, time_step)

# %%
# Make 3-D data(LSTM Requirement) (samples, time steps, features)

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_train.shape, y_train.shape
# Out:
# ((1527, 100, 1), (1527,))

# %% [markdown]
# # Model Building

# %%
import tensorflow as tf
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, LSTM

model = Sequential()

model.add(LSTM(50, return_sequences = True, input_shape = (100, 1)))
model.add(LSTM(50, return_sequences = True))
model.add(LSTM(50))
model.add(Dense(1))

model.compile(loss = 'mean_squared_error', optimizer = 'adam')
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_8 (LSTM)                (None, 100, 50)           10400
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 100, 50)           20200
# _________________________________________________________________
# lstm_10 (LSTM)               (None, 50)                20200
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Predictions

# %%
model.fit(X_train, y_train, validation_data = (X_test, y_test), epochs = 100, batch_size = 64, verbose = True)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 19s 415ms/step - loss: 0.0085 - val_loss: 0.0204
# Epoch 2/100
# 24/24 [==============================] - 9s 383ms/step - loss: 0.0017 - val_loss: 0.0089
# Epoch 3/100
# 24/24 [==============================] - 9s 369ms/step - loss: 8.6342e-04 - val_loss: 0.0040
# Epoch 4/100
# 24/24 [==============================] - 9s 383ms/step - loss: 7.9034e-04 - val_loss: 0.0049
# Epoch 5/100
# 24/24 [==============================] - 9s 383ms/step - loss: 7.7872e-04 - val_loss: 0.0057
# Epoch 6/100
# 24/24 [==============================] - 9s 364ms/step - loss: 7.4214e-04 - val_loss: 0.0047
# Epoch 7/100
# 24/24 [==============================] - 9s 378ms/step - loss: 7.3147e-04 - val_loss: 0.0035
# Epoch 8/100
# 24/24 [==============================] - 9s 368ms/step - loss: 7.0406e-04 - val_loss: 0.0039
# Epoch 9/100
# 24/24 [==============================] - 9s 378ms/step - loss: 6.8651e-04 - val_loss: 0.0038
# Epoch 10/100
# 24/24 [==============================] - 9s 383ms/step - loss: 6.6006e-04 - val_loss: 0.0073
# Epoch 11/100
# 24/24 [==============================] - 9s 382ms/step - loss: 6.2036e-04 - val_loss: 0.0038
# Epoch 12/100
# 24/24 [==============================] - 9s 374ms/step - loss: 5.8100e-04 - val_loss: 0.0053
# Epoch 13/100
# 24/24 [==============================] - 9s 373ms/step - loss: 5.8983e-04 - val_loss: 0.0059
# Epoch 14/100
# 24/24 [==============================] - 10s 421ms/step - loss: 5.2656e-04 - val_loss: 0.0099
# Epoch 15/100
# 24/24 [==============================] - 9s 371ms/step - loss: 5.2078e-04 - val_loss: 0.0102
# Epoch 16/100
# 24/24 [==============================] - 9s 370ms/step - loss: 5.3178e-04 - val_loss: 0.0164
# Epoch 17/100
# 24/24 [==============================] - 9s 371ms/step - loss: 5.3854e-04 - val_loss: 0.0077
# Epoch 18/100
# 24/24 [==============================] - 9s 369ms/step - loss: 4.8029e-04 - val_loss: 0.0134
# Epoch 19/100
# 24/24 [==============================] - 9s 371ms/step - loss: 4.9844e-04 - val_loss: 0.0169
# Epoch 20/100
# 24/24 [==============================] - 9s 374ms/step - loss: 5.0747e-04 - val_loss: 0.0133
# Epoch 21/100
# 24/24 [==============================] - 9s 368ms/step - loss: 4.6978e-04 - val_loss: 0.0068
# Epoch 22/100
# 24/24 [==============================] - 9s 379ms/step - loss: 4.4032e-04 - val_loss: 0.0071
# Epoch 23/100
# 24/24 [==============================] - 9s 368ms/step - loss: 3.9973e-04 - val_loss: 0.0078
# Epoch 24/100
# 24/24 [==============================] - 9s 387ms/step - loss: 3.9185e-04 - val_loss: 0.0073
# Epoch 25/100
# 24/24 [==============================] - 9s 390ms/step - loss: 3.7775e-04 - val_loss: 0.0068
# Epoch 26/100
# 24/24 [==============================] - 9s 373ms/step - loss: 3.7130e-04 - val_loss: 0.0083
# Epoch 27/100
# 24/24 [==============================] - 9s 375ms/step - loss: 3.8663e-04 - val_loss: 0.0068
# Epoch 28/100
# 24/24 [==============================] - 9s 370ms/step - loss: 3.5649e-04 - val_loss: 0.0059
# Epoch 29/100
# 24/24 [==============================] - 9s 379ms/step - loss: 3.5011e-04 - val_loss: 0.0057
# Epoch 30/100
# 24/24 [==============================] - 9s 390ms/step - loss: 3.1206e-04 - val_loss: 0.0060
# Epoch 31/100
# 24/24 [==============================] - 9s 389ms/step - loss: 3.0623e-04 - val_loss: 0.0038
# Epoch 32/100
# 24/24 [==============================] - 9s 381ms/step - loss: 2.9710e-04 - val_loss: 0.0034
# Epoch 33/100
# 24/24 [==============================] - 9s 384ms/step - loss: 2.9140e-04 - val_loss: 0.0037
# Epoch 34/100
# 24/24 [==============================] - 9s 386ms/step - loss: 2.7554e-04 - val_loss: 0.0035
# Epoch 35/100
# 24/24 [==============================] - 9s 358ms/step - loss: 2.6401e-04 - val_loss: 0.0030
# Epoch 36/100
# 24/24 [==============================] - 9s 384ms/step - loss: 2.4764e-04 - val_loss: 0.0052
# Epoch 37/100
# 24/24 [==============================] - 9s 361ms/step - loss: 2.3940e-04 - val_loss: 0.0027
# Epoch 38/100
# 24/24 [==============================] - 9s 389ms/step - loss: 2.2950e-04 - val_loss: 0.0035
# Epoch 39/100
# 24/24 [==============================] - 10s 417ms/step - loss: 2.2824e-04 - val_loss: 0.0025
# Epoch 40/100
# 24/24 [==============================] - 9s 380ms/step - loss: 2.1891e-04 - val_loss: 0.0031
# Epoch 41/100
# 24/24 [==============================] - 9s 384ms/step - loss: 2.1517e-04 - val_loss: 0.0028
# Epoch 42/100
# 24/24 [==============================] - 9s 379ms/step - loss: 2.0589e-04 - val_loss: 0.0020
# Epoch 43/100
# 24/24 [==============================] - 9s 361ms/step - loss: 1.9000e-04 - val_loss: 0.0030
# Epoch 44/100
# 24/24 [==============================] - 9s 382ms/step - loss: 1.8034e-04 - val_loss: 8.5479e-04
# Epoch 45/100
# 24/24 [==============================] - 9s 391ms/step - loss: 2.1047e-04 - val_loss: 9.3030e-04
# Epoch 46/100
# 24/24 [==============================] - 9s 381ms/step - loss: 1.7086e-04 - val_loss: 0.0019
# Epoch 47/100
# 24/24 [==============================] - 9s 387ms/step - loss: 1.6984e-04 - val_loss: 0.0011
# Epoch 48/100
# 24/24 [==============================] - 9s 386ms/step - loss: 1.7471e-04 - val_loss: 0.0025
# Epoch 49/100
# 24/24 [==============================] - 9s 392ms/step - loss: 1.5569e-04 - val_loss: 0.0017
# Epoch 50/100
# 24/24 [==============================] - 9s 373ms/step - loss: 1.5005e-04 - val_loss: 8.4139e-04
# Epoch 51/100
# 24/24 [==============================] - 9s 371ms/step - loss: 1.7294e-04 - val_loss: 6.9537e-04
# Epoch 52/100
# 24/24 [==============================] - 9s 365ms/step - loss: 1.5799e-04 - val_loss: 0.0016
# Epoch 53/100
# 24/24 [==============================] - 9s 372ms/step - loss: 1.5853e-04 - val_loss: 0.0011
# Epoch 54/100
# 24/24 [==============================] - 9s 383ms/step - loss: 1.4964e-04 - val_loss: 0.0019
# Epoch 55/100
# 24/24 [==============================] - 9s 382ms/step - loss: 1.5861e-04 - val_loss: 0.0014
# Epoch 56/100
# 24/24 [==============================] - 9s 375ms/step - loss: 1.3954e-04 - val_loss: 4.4703e-04
# Epoch 57/100
# 24/24 [==============================] - 9s 381ms/step - loss: 1.5615e-04 - val_loss: 0.0017
# Epoch 58/100
# 24/24 [==============================] - 9s 381ms/step - loss: 1.3032e-04 - val_loss: 0.0017
# Epoch 59/100
# 24/24 [==============================] - 9s 390ms/step - loss: 1.2440e-04 - val_loss: 0.0010
# Epoch 60/100
# 24/24 [==============================] - 9s 387ms/step - loss: 1.2567e-04 - val_loss: 8.7343e-04
# Epoch 61/100
# 24/24 [==============================] - 9s 371ms/step - loss: 1.2559e-04 - val_loss: 4.2327e-04
# Epoch 62/100
# 24/24 [==============================] - 9s 369ms/step - loss: 1.3660e-04 - val_loss: 7.3866e-04
# Epoch 63/100
# 24/24 [==============================] - 11s 443ms/step - loss: 1.1922e-04 - val_loss: 6.6740e-04
# Epoch 64/100
# 24/24 [==============================] - 9s 379ms/step - loss: 1.2553e-04 - val_loss: 4.3794e-04
# Epoch 65/100
# 24/24 [==============================] - 9s 385ms/step - loss: 1.4800e-04 - val_loss: 4.3852e-04
# Epoch 66/100
# 24/24 [==============================] - 9s 370ms/step - loss: 1.2183e-04 - val_loss: 8.3007e-04
# Epoch 67/100
# 24/24 [==============================] - 9s 372ms/step - loss: 1.3125e-04 - val_loss: 5.1185e-04
# Epoch 68/100
# 24/24 [==============================] - 9s 383ms/step - loss: 1.2921e-04 - val_loss: 9.0792e-04
# Epoch 69/100
# 24/24 [==============================] - 9s 386ms/step - loss: 1.1336e-04 - val_loss: 6.0439e-04
# Epoch 70/100
# 24/24 [==============================] - 9s 378ms/step - loss: 1.2428e-04 - val_loss: 0.0020
# Epoch 71/100
# 24/24 [==============================] - 9s 371ms/step - loss: 1.4353e-04 - val_loss: 6.8452e-04
# Epoch 72/100
# 24/24 [==============================] - 9s 370ms/step - loss: 1.1984e-04 - val_loss: 5.2458e-04
# Epoch 73/100
# 24/24 [==============================] - 9s 389ms/step - loss: 1.1422e-04 - val_loss: 9.7911e-04
# Epoch 74/100
# 24/24 [==============================] - 9s 378ms/step - loss: 1.2210e-04 - val_loss: 9.2959e-04
# Epoch 75/100
# 24/24 [==============================] - 9s 379ms/step - loss: 1.2509e-04 - val_loss: 7.8242e-04
# Epoch 76/100
# 24/24 [==============================] - 9s 370ms/step - loss: 1.1830e-04 - val_loss: 4.6211e-04
# Epoch 77/100
# 24/24 [==============================] - 9s 375ms/step - loss: 1.1534e-04 - val_loss: 5.6139e-04
# Epoch 78/100
# 24/24 [==============================] - 9s 371ms/step - loss: 1.1200e-04 - val_loss: 6.7463e-04
# Epoch 79/100
# 24/24 [==============================] - 9s 366ms/step - loss: 1.1349e-04 - val_loss: 7.3391e-04
# Epoch 80/100
# 24/24 [==============================] - 9s 374ms/step - loss: 1.1427e-04 - val_loss: 6.0744e-04
# Epoch 81/100
# 24/24 [==============================] - 9s 377ms/step - loss: 1.1718e-04 - val_loss: 4.5906e-04
# Epoch 82/100
# 24/24 [==============================] - 9s 382ms/step - loss: 1.1972e-04 - val_loss: 6.7092e-04
# Epoch 83/100
# 24/24 [==============================] - 9s 374ms/step - loss: 1.1490e-04 - val_loss: 6.4782e-04
# Epoch 84/100
# 24/24 [==============================] - 8s 353ms/step - loss: 1.1804e-04 - val_loss: 6.4124e-04
# Epoch 85/100
# 24/24 [==============================] - 9s 366ms/step - loss: 1.4341e-04 - val_loss: 8.9036e-04
# Epoch 86/100
# 24/24 [==============================] - 9s 377ms/step - loss: 1.2631e-04 - val_loss: 9.8191e-04
# Epoch 87/100
# 24/24 [==============================] - 9s 372ms/step - loss: 1.1685e-04 - val_loss: 6.5153e-04
# Epoch 88/100
# 24/24 [==============================] - 10s 412ms/step - loss: 1.1256e-04 - val_loss: 5.9047e-04
# Epoch 89/100
# 24/24 [==============================] - 9s 375ms/step - loss: 1.1252e-04 - val_loss: 4.4074e-04
# Epoch 90/100
# 24/24 [==============================] - 9s 368ms/step - loss: 1.1224e-04 - val_loss: 0.0013
# Epoch 91/100
# 24/24 [==============================] - 9s 380ms/step - loss: 1.2026e-04 - val_loss: 5.4605e-04
# Epoch 92/100
# 24/24 [==============================] - 9s 369ms/step - loss: 1.1240e-04 - val_loss: 9.0824e-04
# Epoch 93/100
# 24/24 [==============================] - 9s 371ms/step - loss: 1.1326e-04 - val_loss: 5.0393e-04
# Epoch 94/100
# 24/24 [==============================] - 9s 381ms/step - loss: 1.1269e-04 - val_loss: 6.0720e-04
# Epoch 95/100
# 24/24 [==============================] - 9s 371ms/step - loss: 1.1644e-04 - val_loss: 0.0011
# Epoch 96/100
# 24/24 [==============================] - 9s 385ms/step - loss: 1.2305e-04 - val_loss: 8.6145e-04
# Epoch 97/100
# 24/24 [==============================] - 9s 377ms/step - loss: 1.1623e-04 - val_loss: 9.2627e-04
# Epoch 98/100
# 24/24 [==============================] - 9s 378ms/step - loss: 1.1301e-04 - val_loss: 8.3992e-04
# Epoch 99/100
# 24/24 [==============================] - 9s 367ms/step - loss: 1.0823e-04 - val_loss: 0.0010
# Epoch 100/100
# 24/24 [==============================] - 9s 383ms/step - loss: 1.1117e-04 - val_loss: 0.0012

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# %% [markdown]
# # Metrics

# %%
from math import sqrt
from sklearn.metrics import mean_squared_error

rmse_train = sqrt(mean_squared_error(y_train, train_predict))
rmse_test = sqrt(mean_squared_error(y_test, test_predict))
rmse_train, rmse_test
# Out:
# (0.010440197315543638, 0.034084585010603276)

# %% [markdown]
# # Plotting

# %%
train_predict = MMS.inverse_transform(train_predict)
test_predict = MMS.inverse_transform(test_predict)

# %%
look_back = 100

trainPredictPlot = np.empty_like(df_high)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back: len(train_predict) + look_back, :] = train_predict

testPredictPlot = np.empty_like(df_high)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict) + (look_back * 2) + 1: len(df_high) - 1, :] = test_predict

# %%
plt.plot(MMS.inverse_transform(df_high))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)

plt.legend(labels = ['Complete data', 'Train data', 'Predicted data'])
plt.show()
